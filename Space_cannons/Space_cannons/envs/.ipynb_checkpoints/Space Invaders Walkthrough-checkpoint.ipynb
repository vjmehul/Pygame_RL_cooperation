# %% [markdown]
# # 0. Install Dependencies

# %%
# !pip install tensorflow==2.3.1 gym keras-rl2 gym[atari]
# Out:
# Collecting tensorflow==2.3.1
#   Using cached tensorflow-2.3.1-cp37-cp37m-win_amd64.whl (342.5 MB)
# Requirement already satisfied: gym in c:\users\shizu\anaconda3\lib\site-packages (0.18.0)
# Requirement already satisfied: keras-rl2 in c:\users\shizu\anaconda3\lib\site-packages (1.0.4)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\shizu\anaconda3\lib\site-packages (from tensorflow==2.3.1) (1.32.0)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\shizu\anaconda3\lib\site-packages (from tensorflow==2.3.1) (1.12.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\shizu\anaconda3\lib\site-packages (from tensorflow==2.3.1) (1.15.0)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\shizu\anaconda3\lib\site-packages (from tensorflow==2.3.1) (0.12.0)
# Collecting tensorboard<3,>=2.3.0
#   Using cached tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in c:\users\shizu\anaconda3\lib\site-packages (from tensorflow==2.3.1) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\shizu\anaconda3\lib\site-packages (from tensorflow==2.3.1) (1.1.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\shizu\anaconda3\lib\site-packages (from tensorflow==2.3.1) (2.10.0)
# Collecting numpy<1.19.0,>=1.16.0
#   Using cached numpy-1.18.5-cp37-cp37m-win_amd64.whl (12.7 MB)
# Requirement already satisfied: google-pasta>=0.1.8 in c:\users\shizu\anaconda3\lib\site-packages (from tensorflow==2.3.1) (0.2.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\shizu\anaconda3\lib\site-packages (from tensorflow==2.3.1) (0.36.2)
# Collecting gast==0.3.3
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\shizu\anaconda3\lib\site-packages (from tensorflow==2.3.1) (3.12.2)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\shizu\anaconda3\lib\site-packages (from tensorflow==2.3.1) (1.6.3)
# Collecting tensorflow-estimator<2.4.0,>=2.3.0
#   Using cached tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\shizu\anaconda3\lib\site-packages (from tensorflow==2.3.1) (3.3.0)
# Requirement already satisfied: scipy in c:\users\shizu\appdata\roaming\python\python37\site-packages (from gym) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in c:\users\shizu\anaconda3\lib\site-packages (from gym) (1.6.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in c:\users\shizu\anaconda3\lib\site-packages (from gym) (1.5.0)
# Requirement already satisfied: Pillow<=7.2.0 in c:\users\shizu\anaconda3\lib\site-packages (from gym) (7.2.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\shizu\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1) (1.6.0.post3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\shizu\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1) (3.2.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\shizu\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1) (0.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\shizu\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1) (49.6.0.post20200814)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\shizu\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1) (0.6.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\shizu\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\shizu\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1) (1.18.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\shizu\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.1) (2.24.0)
# Requirement already satisfied: future in c:\users\shizu\anaconda3\lib\site-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.18.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\shizu\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.1) (1.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\shizu\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.1) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\shizu\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\shizu\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.1) (4.1.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in c:\users\shizu\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.1) (4.6)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\shizu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\shizu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\shizu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.1) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shizu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.1) (2020.6.20)
# Requirement already satisfied: zipp>=0.5 in c:\users\shizu\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.1) (3.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\shizu\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.1) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\shizu\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.1) (0.4.8)
# Installing collected packages: numpy, tensorboard, gast, tensorflow-estimator, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Rolling back uninstall of numpy
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy-1.19.5.dist-info\
#    from c:\users\shizu\anaconda3\lib\site-packages\~umpy-1.19.5.dist-info
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\.libs\libopenblas.wcdjnk7yvmpzq2me2zzhjjrj3jikndb7.gfortran-win_amd64.dll
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-oyh_b6ih\libopenblas.wcdjnk7yvmpzq2me2zzhjjrj3jikndb7.gfortran-win_amd64.dll
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\__config__.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\__config__.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\__init__.cython-30.pxd
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\__init__.cython-30.pxd
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\__init__.pxd
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\__init__.pxd
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\__init__.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\__init__.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\__pycache__\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\~_pycache__
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\_distributor_init.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\_distributor_init.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\_globals.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\_globals.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\_pytesttester.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\_pytesttester.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\compat\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\~ompat
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\conftest.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\conftest.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\core\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\~ore
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\ctypeslib.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\ctypeslib.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\__config__.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\__config__.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\__init__.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\__init__.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\__pycache__\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\~_pycache__
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\_shell_utils.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\_shell_utils.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\ccompiler.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\ccompiler.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\command\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\~ommand
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\conv_template.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\conv_template.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\core.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\core.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\cpuinfo.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\cpuinfo.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\exec_command.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\exec_command.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\extension.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\extension.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\fcompiler\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\~compiler
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\from_template.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\from_template.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\intelccompiler.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\intelccompiler.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\lib2def.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\lib2def.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\line_endings.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\line_endings.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\log.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\log.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\mingw32ccompiler.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\mingw32ccompiler.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\mingw\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\~ingw
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\misc_util.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\misc_util.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\msvc9compiler.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\msvc9compiler.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\msvccompiler.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\msvccompiler.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\npy_pkg_config.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\npy_pkg_config.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\numpy_distribution.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\numpy_distribution.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\pathccompiler.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\pathccompiler.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\setup.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\setup.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\system_info.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\system_info.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\tests\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\~ests
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\distutils\unixccompiler.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\distutils\unixccompiler.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\doc\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\~oc
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\dual.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\dual.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\f2py\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\~2py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\fft\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\~ft
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\lib\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\~ib
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\license.txt
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\license.txt
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\linalg\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\~inalg
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\ma\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\~a
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\matlib.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\matlib.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\matrixlib\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\~atrixlib
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\polynomial\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\~olynomial
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\random\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\~andom
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\setup.py
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'C:\\Users\\Shizu\\Anaconda3\\Lib\\site-packages\\numpy\\.libs\\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll'
# Consider using the `--user` option or check the permissions.
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\setup.py
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\testing\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\~esting
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\tests\
#    from c:\users\shizu\anaconda3\lib\site-packages\numpy\~ests
#   Moving to c:\users\shizu\anaconda3\lib\site-packages\numpy\version.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-9xr62i0_\version.py
#   Moving to c:\users\shizu\anaconda3\scripts\f2py-script.py
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-z5nl8o5_\f2py-script.py
#   Moving to c:\users\shizu\anaconda3\scripts\f2py.exe
#    from C:\Users\Shizu\AppData\Local\Temp\pip-uninstall-z5nl8o5_\f2py.exe

# %% [markdown]
# # 1. Test Random Environment with OpenAI Gym

# %%
import gym 
import random
# Out:
# C:\Users\Shizu\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Shizu\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\Shizu\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.wcdjnk7yvmpzq2me2zzhjjrj3jikndb7.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
env = gym.make('SpaceInvaders-v0')
height, width, channels = env.observation_space.shape
actions = env.action_space.n

# %%
env.unwrapped.get_action_meanings()
# Out:
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = random.choice([0,1,2,3,4,5])
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:240.0
# Episode:2 Score:75.0
# Episode:3 Score:280.0
# Episode:4 Score:140.0
# Episode:5 Score:80.0

# %%
env.observation_space
# Out:
# Box(0, 255, (210, 160, 3), uint8)

# %% [markdown]
# # 2. Create a Deep Learning Model with Keras

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Convolution2D
from tensorflow.keras.optimizers import Adam

# %%
def build_model(height, width, channels, actions):
    model = Sequential()
    model.add(Convolution2D(32, (8,8), strides=(4,4), activation='relu', input_shape=(3,height, width, channels)))
    model.add(Convolution2D(64, (4,4), strides=(2,2), activation='relu'))
    model.add(Convolution2D(64, (3,3), activation='relu'))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(actions, activation='linear'))
    return model

# %%
del model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a7ab210f85a1> in <module>
# ----> 1 del model
#
# NameError: name 'model' is not defined

# %%
model = build_model(height, width, channels, actions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-9b37718e79eb> in <module>
# ----> 1 model = build_model(height, width, channels, actions)
#
# <ipython-input-7-4291ef8d8175> in build_model(height, width, channels, actions)
#       1 def build_model(height, width, channels, actions):
#       2     model = Sequential()
# ----> 3     model.add(Convolution2D(32, (8,8), strides=(4,4), activation='relu', input_shape=(3,height, width, channels)))
#       4     model.add(Convolution2D(64, (4,4), strides=(2,2), activation='relu'))
#       5     model.add(Convolution2D(64, (3,3), activation='relu'))
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\sequential.py in add(self, layer)
#     176           # and create the node connecting the current layer
#     177           # to the input layer we just created.
# --> 178           layer(x)
#     179           set_inputs = True
#     180
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     810         # are casted, not before.
#     811         input_spec.assert_input_compatibility(self.input_spec, inputs,
# --> 812                                               self.name)
#     813         graph = backend.get_graph()
#     814         with graph.as_default(), backend.name_scope(self._name_scope()):
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\engine\input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     175                          'expected ndim=' + str(spec.ndim) + ', found ndim=' +
#     176                          str(ndim) + '. Full shape received: ' +
# --> 177                          str(x.shape.as_list()))
#     178     if spec.max_ndim is not None:
#     179       ndim = x.shape.ndims
#
# ValueError: Input 0 of layer conv2d_1 is incompatible with the layer: expected ndim=4, found ndim=5. Full shape received: [None, 3, 210, 160, 3]

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5f15418b3570> in <module>
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined

# %% [markdown]
# # 3. Build Agent with Keras-RL

# %%
from rl.agents import DQNAgent
from rl.memory import SequentialMemory
from rl.policy import LinearAnnealedPolicy, EpsGreedyQPolicy

# %%
def build_agent(model, actions):
    policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps', value_max=1., value_min=.1, value_test=.2, nb_steps=10000)
    memory = SequentialMemory(limit=1000, window_length=3)
    dqn = DQNAgent(model=model, memory=memory, policy=policy,
                  enable_dueling_network=True, dueling_type='avg', 
                   nb_actions=actions, nb_steps_warmup=1000
                  )
    return dqn

# %%
dqn = build_agent(model, actions)
dqn.compile(Adam(lr=1e-4))

# %%
dqn.fit(env, nb_steps=10000, visualize=False, verbose=2)
# Out:
# Training for 10000 steps ...
#  1197/10000: episode: 1, duration: 16.708s, episode steps: 1197, steps per second:  72, episode reward: 275.000, mean reward:  0.230 [ 0.000, 30.000], mean action: 2.595 [0.000, 5.000],  loss: 27.396054, mean_q: 11.414030, mean_eps: 0.901135
#  1890/10000: episode: 2, duration: 41.929s, episode steps: 693, steps per second:  17, episode reward: 135.000, mean reward:  0.195 [ 0.000, 30.000], mean action: 2.505 [0.000, 5.000],  loss: 1.129293, mean_q: 9.534999, mean_eps: 0.861130
#  2441/10000: episode: 3, duration: 34.082s, episode steps: 551, steps per second:  16, episode reward: 140.000, mean reward:  0.254 [ 0.000, 30.000], mean action: 2.566 [0.000, 5.000],  loss: 1.161340, mean_q: 10.541823, mean_eps: 0.805150
#  3449/10000: episode: 4, duration: 61.689s, episode steps: 1008, steps per second:  16, episode reward: 320.000, mean reward:  0.317 [ 0.000, 30.000], mean action: 2.569 [0.000, 5.000],  loss: 1.287153, mean_q: 11.357870, mean_eps: 0.734995
#  4513/10000: episode: 5, duration: 64.572s, episode steps: 1064, steps per second:  16, episode reward: 195.000, mean reward:  0.183 [ 0.000, 30.000], mean action: 2.456 [0.000, 5.000],  loss: 0.497081, mean_q: 9.330520, mean_eps: 0.641755
#  5310/10000: episode: 6, duration: 48.119s, episode steps: 797, steps per second:  17, episode reward: 180.000, mean reward:  0.226 [ 0.000, 30.000], mean action: 2.423 [0.000, 5.000],  loss: 0.531408, mean_q: 10.102600, mean_eps: 0.558010
#  6025/10000: episode: 7, duration: 43.741s, episode steps: 715, steps per second:  16, episode reward: 125.000, mean reward:  0.175 [ 0.000, 25.000], mean action: 2.438 [0.000, 5.000],  loss: 0.468921, mean_q: 10.508261, mean_eps: 0.489970
#  6561/10000: episode: 8, duration: 33.157s, episode steps: 536, steps per second:  16, episode reward: 135.000, mean reward:  0.252 [ 0.000, 30.000], mean action: 2.914 [0.000, 5.000],  loss: 0.732872, mean_q: 10.142298, mean_eps: 0.433675
#  7091/10000: episode: 9, duration: 32.751s, episode steps: 530, steps per second:  16, episode reward: 85.000, mean reward:  0.160 [ 0.000, 25.000], mean action: 2.574 [0.000, 5.000],  loss: 0.413073, mean_q: 10.873431, mean_eps: 0.385705
#  7683/10000: episode: 10, duration: 37.227s, episode steps: 592, steps per second:  16, episode reward: 90.000, mean reward:  0.152 [ 0.000, 25.000], mean action: 2.720 [0.000, 5.000],  loss: 0.232420, mean_q: 10.754884, mean_eps: 0.335215
#  8301/10000: episode: 11, duration: 38.207s, episode steps: 618, steps per second:  16, episode reward: 120.000, mean reward:  0.194 [ 0.000, 30.000], mean action: 2.620 [0.000, 5.000],  loss: 0.504104, mean_q: 10.189123, mean_eps: 0.280765
#  9127/10000: episode: 12, duration: 50.743s, episode steps: 826, steps per second:  16, episode reward: 180.000, mean reward:  0.218 [ 0.000, 25.000], mean action: 2.390 [0.000, 5.000],  loss: 0.271572, mean_q: 9.491021, mean_eps: 0.215785
#  9672/10000: episode: 13, duration: 33.557s, episode steps: 545, steps per second:  16, episode reward: 20.000, mean reward:  0.037 [ 0.000, 10.000], mean action: 2.550 [0.000, 5.000],  loss: 0.200701, mean_q: 8.646260, mean_eps: 0.154090
# done, took 556.993 seconds

# %%
scores = dqn.test(env, nb_episodes=10, visualize=True)
print(np.mean(scores.history['episode_reward']))
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 90.000, steps: 499
# Episode 2: reward: 220.000, steps: 965
# Episode 3: reward: 230.000, steps: 1224
# Episode 4: reward: 240.000, steps: 715
# Episode 5: reward: 635.000, steps: 1267
# Episode 6: reward: 205.000, steps: 673
# Episode 7: reward: 435.000, steps: 1096
# Episode 8: reward: 315.000, steps: 1166
# Episode 9: reward: 170.000, steps: 679
# Episode 10: reward: 280.000, steps: 871
# 282.0

# %% [markdown]
# # 4. Reloading Agent from Memory

# %%
dqn.save_weights('SavedWeights/10k-Fast/dqn_weights.h5f')

# %%
del model, dqn

# %%
dqn.load_weights('SavedWeights/1m/dqn_weights.h5f')
